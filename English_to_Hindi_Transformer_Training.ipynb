# %% [markdown]
# <a href="https://colab.research.google.com/github/varun29-git/translation_model/blob/main/English_to_Hindi_Transformer_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/varun29-git/translation_model
# !git pull
# Out:
# Cloning into 'translation_model'...
# remote: Enumerating objects: 582, done.
# remote: Counting objects: 100% (582/582), done.
# remote: Compressing objects: 100% (525/525), done.
# remote: Total 582 (delta 33), reused 563 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (582/582), 1.98 MiB | 17.97 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 386 bytes | 386.00 KiB/s, done.
# From https://github.com/varun29-git/translation_model
#    8478104..d6a34ff  main       -> origin/main
# Updating 8478104..d6a34ff
# Fast-forward
#  config.py | 6 +++---
#  train.py  | 1 +
#  2 files changed, 4 insertions(+), 3 deletions(-)

# %%
# %cd translation_model
# !pip install -r requirements.txt
# Out:
# /content/translation_model/translation_model/translation_model/translation_model/translation_model/translation_model/translation_model/translation_model/translation_model/translation_model
# ...

# %%
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
print(f"Device Name: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")
# Out:
# GPU Available: True
# Device Name: Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python train.py
# Out:
# 2026-01-10 08:28:12.036167: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768033692.056067   17174 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768033692.062111   17174 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768033692.077123   17174 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os
from config import get_config

config = get_config()
folder = config['model_folder']

print(f"Checking directory: {folder}")
# !ls -lh "{folder}"
# Out:
# Checking directory: weights
# total 7.6G
# -rw-r--r-- 1 root root 310M Jan 10 08:36 t_model_00.pt
# -rw-r--r-- 1 root root 310M Jan 10 08:45 t_model_01.pt
# -rw-r--r-- 1 root root 310M Jan 10 08:53 t_model_02.pt
# -rw-r--r-- 1 root root 310M Jan 10 09:02 t_model_03.pt
# -rw-r--r-- 1 root root 310M Jan 10 09:10 t_model_04.pt
# -rw-r--r-- 1 root root 310M Jan 10 09:19 t_model_05.pt
# -rw-r--r-- 1 root root 310M Jan 10 09:27 t_model_06.pt
# -rw-r--r-- 1 root root 310M Jan 10 09:35 t_model_07.pt
# -rw-r--r-- 1 root root 310M Jan 10 09:44 t_model_08.pt
# -rw-r--r-- 1 root root 310M Jan 10 09:52 t_model_09.pt
# -rw-r--r-- 1 root root 310M Jan 10 10:00 t_model_10.pt
# -rw-r--r-- 1 root root 310M Jan 10 10:09 t_model_11.pt
# -rw-r--r-- 1 root root 310M Jan 10 10:17 t_model_12.pt
# -rw-r--r-- 1 root root 310M Jan 10 10:26 t_model_13.pt
# -rw-r--r-- 1 root root 310M Jan 10 10:34 t_model_14.pt
# -rw-r--r-- 1 root root 310M Jan 10 10:42 t_model_15.pt
# ...

# %%
# !mkdir -p /content/drive/MyDrive/Hindi_Translator_Project

# !cp -v weights/t_model_24.pt /content/drive/MyDrive/Hindi_Translator_Project/

# !cp -v tokenizer_en.json /content/drive/MyDrive/Hindi_Translator_Project/
# !cp -v tokenizer_hi.json /content/drive/MyDrive/Hindi_Translator_Project/

print("Backup to Google Drive complete!")
# Out:
# 'weights/t_model_24.pt' -> '/content/drive/MyDrive/Hindi_Translator_Project/t_model_24.pt'
# 'tokenizer_en.json' -> '/content/drive/MyDrive/Hindi_Translator_Project/tokenizer_en.json'
# 'tokenizer_hi.json' -> '/content/drive/MyDrive/Hindi_Translator_Project/tokenizer_hi.json'
# Backup to Google Drive complete!
